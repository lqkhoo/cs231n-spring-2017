# %% [markdown]
# ## Bounding boxes

# %% [markdown]
# This notebook handles the extraction of bounding boxes from the original XML data to something more lightweight, for our selected synsets. Bounding boxes which have been defined to overlap regions outside of the image are clipped to the bounds of the image.

# %%
import os, os.path
import xml.etree.ElementTree as ET

images_path = 'data/images/bboxfiltered/'
bbox_annotations_path = 'data/bbox/Annotation/'

synsets = [f for f in os.listdir(images_path)
                if not os.path.isfile(os.path.join(images_path, f))]

i = 0
for synset in synsets:
    
    dir_path = bbox_annotations_path + synset + "/"
    files = [f for f in os.listdir(dir_path)
                 if os.path.isfile(os.path.join(dir_path, f))]
    
    output_path = 'data/bbox/tsv/' + synset + ".tsv"
    with open(output_path, "w") as f:
        
        print("Processing synset " + str(i) + ": " + synset)
    
        for file in files:
            correction_performed = False

            # Traverse XML tree and get the relevant values
            tree = ET.parse(dir_path + str(file))
            root = tree.getroot()
            
            filename = [child for child in root if child.tag == "filename"][0].text
            size = [child for child in root if child.tag == "size"][0]
            
            width = int([child for child in size if child.tag == "width"][0].text)
            height = int([child for child in size if child.tag == "height"][0].text)
            
            obj = [child for child in root if child.tag == "object"][0]
            # AFAIK there is only one bounding box label per image
            bndbox = [child for child in obj if child.tag == "bndbox"][0]
            xmin = int([child for child in bndbox if child.tag == "xmin"][0].text)
            ymin = int([child for child in bndbox if child.tag == "ymin"][0].text)
            xmax = int([child for child in bndbox if child.tag == "xmax"][0].text)
            ymax = int([child for child in bndbox if child.tag == "ymax"][0].text)
            
            # This is to correct for out-of-bounds bounding boxes
            
            if xmax > width:
                xmax = min(xmax, width)
                correction_performed = True    
            if ymax > height:
                ymax = min(ymax, height)
                correction_performed = True
            if xmin < 0:
                xmin = max(xmin, 0)
                correction_performed = True
            if ymin < 0:
                ymin = max(ymin, 0)
                correction_performed = True
            
            if correction_performed:
                print("  WARN: corrected oob bbox.")
            
            output_str = "".join([filename + ".JPEG", 
                                   "\t", str(width),
                                   "\t", str(height),
                                   "\t", str(xmin), 
                                   "\t", str(ymin), 
                                   "\t", str(xmax), 
                                   "\t", str(ymax), 
                                   "\n"])
            f.write(output_str)
    
    i+=1
    
print("All done.")
# Out:
# Processing synset 0: n03692522
# Processing synset 1: n04179913
# Processing synset 2: n09217230
# Processing synset 3: n03314780
# Processing synset 4: n04325704
#   WARN: corrected oob bbox.
# Processing synset 5: n03982430
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
# Processing synset 6: n02077923
# Processing synset 7: n02321529
# Processing synset 8: n04317175
# Processing synset 9: n04194289
# Processing synset 10: n06277135
# Processing synset 11: n02443484
# Processing synset 12: n01950731
# Processing synset 13: n01774384
#   WARN: corrected oob bbox.
# Processing synset 14: n02395406
# Processing synset 15: n03179701
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
# Processing synset 16: n04613696
# Processing synset 17: n04256520
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
# Processing synset 18: n03838899
# Processing synset 19: n02013706
# Processing synset 20: n04209133
# Processing synset 21: n04330267
#   WARN: corrected oob bbox.
# Processing synset 22: n02788148
# Processing synset 23: n02906734
# Processing synset 24: n03874293
#   WARN: corrected oob bbox.
# Processing synset 25: n03447721
# Processing synset 26: n03017168
# Processing synset 27: n03837869
# Processing synset 28: n02256656
# Processing synset 29: n07920052
# Processing synset 30: n03657121
# Processing synset 31: n02430045
# Processing synset 32: n03599486
# Processing synset 33: n02768226
#   WARN: corrected oob bbox.
# Processing synset 34: n02990373
# Processing synset 35: n02410509
# Processing synset 36: n02231487
# Processing synset 37: n03770439
# Processing synset 38: n04379243
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
# Processing synset 39: n04133789
# Processing synset 40: n03814906
#   WARN: corrected oob bbox.
# Processing synset 41: n03180011
#   WARN: corrected oob bbox.
# Processing synset 42: n03197337
# Processing synset 43: n03761084
# Processing synset 44: n03814639
# Processing synset 45: n03207743
# Processing synset 46: n02279972
# Processing synset 47: n03388043
# Processing synset 48: n03691459
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
# Processing synset 49: n04429376
# Processing synset 50: n02084071
# Processing synset 51: n04370048
#   WARN: corrected oob bbox.
# Processing synset 52: n02281787
# Processing synset 53: n09288635
# Processing synset 54: n04149813
# Processing synset 55: n04326547
#   WARN: corrected oob bbox.
# Processing synset 56: n03089624
# Processing synset 57: n04532670
# Processing synset 58: n04428191
# Processing synset 59: n07873807
# Processing synset 60: n13104059
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
# Processing synset 61: n04023962
# Processing synset 62: n01855032
# Processing synset 63: n04479046
# Processing synset 64: n04562935
# Processing synset 65: n04008634
# Processing synset 66: n01644373
# Processing synset 67: n03505667
# Processing synset 68: n07579787
# Processing synset 69: n04107743
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
# Processing synset 70: n03513137
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
# Processing synset 71: n03793489
#   WARN: corrected oob bbox.
# Processing synset 72: n02169497
# Processing synset 73: n02472293
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
# Processing synset 74: n04275548
# Processing synset 75: n02108089
# Processing synset 76: n03792972
# Processing synset 77: n04099969
# Processing synset 78: n09450163
#   WARN: corrected oob bbox.
# Processing synset 79: n04102406
#   WARN: corrected oob bbox.
# Processing synset 80: n02666196
# Processing synset 81: n03930313
# Processing synset 82: n01853498
# Processing synset 83: n04525038
# Processing synset 84: n02484322
# Processing synset 85: n01641391
# Processing synset 86: n02280649
# Processing synset 87: n07584110
# Processing synset 88: n02268853
# Processing synset 89: n01632458
# Processing synset 90: n04456115
# Processing synset 91: n03649909
# Processing synset 92: n04201297
# Processing synset 93: n04021028
#   WARN: corrected oob bbox.
# Processing synset 94: n03327234
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
# Processing synset 95: n03273913
#   WARN: corrected oob bbox.
# Processing synset 96: n03854065
# Processing synset 97: n01917289
# Processing synset 98: n03902125
# Processing synset 99: n04019541
#   WARN: corrected oob bbox.
# Processing synset 100: n04608329
#   WARN: corrected oob bbox.
# Processing synset 101: n02236044
# Processing synset 102: n04243546
# Processing synset 103: n02403003
# Processing synset 104: n03874599
# Processing synset 105: n02841315
# Processing synset 106: n02113799
#   WARN: corrected oob bbox.
# Processing synset 107: n09332890
# Processing synset 108: n00017222
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
# Processing synset 109: n01605630
# Processing synset 110: n04465501
# Processing synset 111: n02843684
# Processing synset 112: n03658185
# Processing synset 113: n04560804
# Processing synset 114: n02730930
# Processing synset 115: n02259212
#   WARN: corrected oob bbox.
# Processing synset 116: n04405762
# Processing synset 117: n03773035
#   WARN: corrected oob bbox.
# Processing synset 118: n03995372
# Processing synset 119: n09874725
# Processing synset 120: n07711569
# Processing synset 121: n02002724
# Processing synset 122: n07874780
# Processing synset 123: n04335886
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
# Processing synset 124: n06359193
#   WARN: corrected oob bbox.
# Processing synset 125: n03733131
# Processing synset 126: n02132136
# Processing synset 127: n03636649
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
# Processing synset 128: n04328186
# Processing synset 129: n02999410
# Processing synset 130: n04251791
# Processing synset 131: n03998194
#   WARN: corrected oob bbox.
# Processing synset 132: n02277742
# Processing synset 133: n07875152
# Processing synset 134: n09246464
# Processing synset 135: n02508021
# Processing synset 136: n04070727
# Processing synset 137: n04067472
# Processing synset 138: n02791270
# Processing synset 139: n02802544
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
# Processing synset 140: n03325088
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
# Processing synset 141: n02799071
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
# Processing synset 142: n03781244
#   WARN: corrected oob bbox.
# Processing synset 143: n04118538
# Processing synset 144: n04447861
# Processing synset 145: n01770393
# Processing synset 146: n04004767
# Processing synset 147: n04398044
# Processing synset 148: n01784675
# Processing synset 149: n02165456
# Processing synset 150: n03803284
# Processing synset 151: n03329302
#   WARN: corrected oob bbox.
# Processing synset 152: n02892201
# Processing synset 153: n01629819
# Processing synset 154: n01983481
# Processing synset 155: n03733281
# Processing synset 156: n03530642
# Processing synset 157: n03001627
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
# Processing synset 158: n03992509
# Processing synset 159: n03505504
# Processing synset 160: n04467665
# Processing synset 161: n02165105
# Processing synset 162: n03636248
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
# Processing synset 163: n03207941
#   WARN: corrected oob bbox.
# Processing synset 164: n03680355
# Processing synset 165: n03532672
# Processing synset 166: n04254777
# Processing synset 167: n03903868
# Processing synset 168: n02909870
# Processing synset 169: n01986214
# Processing synset 170: n03614007
# Processing synset 171: n03255030
# Processing synset 172: n02958343
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
# Processing synset 173: n01503061
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
# Processing synset 174: n02948072
# Processing synset 175: n03619890
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
# Processing synset 176: n02950826
# Processing synset 177: n03042490
# Processing synset 178: n04350905
# Processing synset 179: n04592741
#   WARN: corrected oob bbox.
# Processing synset 180: n02769748
# Processing synset 181: n02415577
# Processing synset 182: n01641577
# Processing synset 183: n09468604
#   WARN: corrected oob bbox.
# Processing synset 184: n03085013
# Processing synset 185: n02699494
# Processing synset 186: n04311004
# Processing synset 187: n09428293
# Processing synset 188: n02691156
#   WARN: corrected oob bbox.
# Processing synset 189: n04069434
# Processing synset 190: n04487081
# Processing synset 191: n03980874
# Processing synset 192: n02815834
# Processing synset 193: n04152593
# Processing synset 194: n03637318
# Processing synset 195: n03759954
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
# Processing synset 196: n03187595
# Processing synset 197: n03665366
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
# Processing synset 198: n03250847
# Processing synset 199: n04025508
# Processing synset 200: n01855672
# Processing synset 201: n07836838
#   WARN: corrected oob bbox.
# Processing synset 202: n04313503
# Processing synset 203: n04366367
# Processing synset 204: n02374451
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
# Processing synset 205: n03416489
# Processing synset 206: n02226429
# Processing synset 207: n03642806
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
# Processing synset 208: n09421951
# Processing synset 209: n02281406
# Processing synset 210: n12102133
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
# Processing synset 211: n01871265
# Processing synset 212: n02879718
# Processing synset 213: n02731629
# Processing synset 214: n03868863
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
#   WARN: corrected oob bbox.
# Processing synset 215: n04540053
# Processing synset 216: n04435653
# Processing synset 217: n02963159
# All done.

# %%
# Output as json instead

import os
import json

INPUT_DIR = "data/bbox/tsv/"
OUTPUT_DIR = "data/bbox/json/"

files = [f for f in os.listdir(INPUT_DIR) if os.path.isfile(os.path.join(INPUT_DIR, f))]

for f in files:
    print("Processing: " + f)
    filepath = os.path.join(INPUT_DIR, f)
    dic = {}
    with open(filepath) as fp:
        data = fp.readlines()
        data = [x.strip() for x in data]
        for item in data:
            ls = item.split('\t')
            key = ls[0]
            value = list(map(int, ls[1:]))
            dic[key] = value
        
    with open(os.path.join(OUTPUT_DIR, f.split('.')[0] + ".json"), 'w') as fp:
        json.dump(dic, fp)
        
print("All done.")
# Out:
# Processing: n01983481.tsv
# Processing: n07711569.tsv
# Processing: n03327234.tsv
# Processing: n09421951.tsv
# Processing: n03733131.tsv
# Processing: n04330267.tsv
# Processing: n04070727.tsv
# Processing: n03530642.tsv
# Processing: n01632458.tsv
# Processing: n03992509.tsv
# Processing: n04025508.tsv
# Processing: n03180011.tsv
# Processing: n02280649.tsv
# Processing: n04317175.tsv
# Processing: n02281787.tsv
# Processing: n03532672.tsv
# Processing: n04311004.tsv
# Processing: n04405762.tsv
# Processing: n09428293.tsv
# Processing: n07873807.tsv
# Processing: n03207743.tsv
# Processing: n02990373.tsv
# Processing: n04133789.tsv
# Processing: n03692522.tsv
# Processing: n04525038.tsv
# Processing: n00017222.tsv
# Processing: n03874599.tsv
# Processing: n04465501.tsv
# Processing: n03636649.tsv
# Processing: n02950826.tsv
# Processing: n04479046.tsv
# Processing: n04608329.tsv
# Processing: n03250847.tsv
# Processing: n06277135.tsv
# Processing: n02948072.tsv
# Processing: n03447721.tsv
# Processing: n03637318.tsv
# Processing: n04201297.tsv
# Processing: n02906734.tsv
# Processing: n04019541.tsv
# Processing: n02699494.tsv
# Processing: n03995372.tsv
# Processing: n04398044.tsv
# Processing: n03759954.tsv
# Processing: n02843684.tsv
# Processing: n02963159.tsv
# Processing: n04467665.tsv
# Processing: n03649909.tsv
# Processing: n07920052.tsv
# Processing: n04004767.tsv
# Processing: n03874293.tsv
# Processing: n09332890.tsv
# Processing: n07875152.tsv
# Processing: n09217230.tsv
# Processing: n03614007.tsv
# Processing: n02002724.tsv
# Processing: n04335886.tsv
# Processing: n02508021.tsv
# Processing: n03781244.tsv
# Processing: n02277742.tsv
# Processing: n03838899.tsv
# Processing: n02113799.tsv
# Processing: n03982430.tsv
# Processing: n04435653.tsv
# Processing: n04366367.tsv
# Processing: n03930313.tsv
# Processing: n01641391.tsv
# Processing: n02268853.tsv
# Processing: n03793489.tsv
# Processing: n03761084.tsv
# Processing: n04370048.tsv
# Processing: n03770439.tsv
# Processing: n03657121.tsv
# Processing: n04256520.tsv
# Processing: n02958343.tsv
# Processing: n02731629.tsv
# Processing: n01917289.tsv
# Processing: n04562935.tsv
# Processing: n01644373.tsv
# Processing: n03680355.tsv
# Processing: n04099969.tsv
# Processing: n09288635.tsv
# Processing: n03197337.tsv
# Processing: n04326547.tsv
# Processing: n03814639.tsv
# Processing: n02279972.tsv
# Processing: n02768226.tsv
# Processing: n02841315.tsv
# Processing: n04275548.tsv
# Processing: n07584110.tsv
# Processing: n01855672.tsv
# Processing: n02013706.tsv
# Processing: n09246464.tsv
# Processing: n02472293.tsv
# Processing: n04447861.tsv
# Processing: n01950731.tsv
# Processing: n04118538.tsv
# Processing: n04023962.tsv
# Processing: n02415577.tsv
# Processing: n04325704.tsv
# Processing: n02165105.tsv
# Processing: n09874725.tsv
# Processing: n02410509.tsv
# Processing: n03042490.tsv
# Processing: n03980874.tsv
# Processing: n03792972.tsv
# Processing: n03691459.tsv
# Processing: n03255030.tsv
# Processing: n03658185.tsv
# Processing: n02730930.tsv
# Processing: n09450163.tsv
# Processing: n02691156.tsv
# Processing: n04152593.tsv
# Processing: n04179913.tsv
# Processing: n04102406.tsv
# Processing: n02999410.tsv
# Processing: n07579787.tsv
# Processing: n01770393.tsv
# Processing: n02909870.tsv
# Processing: n03179701.tsv
# Processing: n02430045.tsv
# Processing: n04328186.tsv
# Processing: n03854065.tsv
# Processing: n04209133.tsv
# Processing: n04429376.tsv
# Processing: n02108089.tsv
# Processing: n02791270.tsv
# Processing: n02666196.tsv
# Processing: n03085013.tsv
# Processing: n02236044.tsv
# Processing: n02484322.tsv
# Processing: n03505504.tsv
# Processing: n13104059.tsv
# Processing: n03868863.tsv
# Processing: n07836838.tsv
# Processing: n02769748.tsv
# Processing: n04008634.tsv
# Processing: n03902125.tsv
# Processing: n02256656.tsv
# Processing: n12102133.tsv
# Processing: n04350905.tsv
# Processing: n03619890.tsv
# Processing: n04613696.tsv
# Processing: n03388043.tsv
# Processing: n09468604.tsv
# Processing: n02879718.tsv
# Processing: n04313503.tsv
# Processing: n02395406.tsv
# Processing: n04069434.tsv
# Processing: n03187595.tsv
# Processing: n01629819.tsv
# Processing: n04592741.tsv
# Processing: n03207941.tsv
# Processing: n04487081.tsv
# Processing: n04021028.tsv
# Processing: n04251791.tsv
# Processing: n03314780.tsv
# Processing: n03017168.tsv
# Processing: n02403003.tsv
# Processing: n04532670.tsv
# Processing: n01853498.tsv
# Processing: n04254777.tsv
# Processing: n02443484.tsv
# Processing: n04149813.tsv
# Processing: n04107743.tsv
# Processing: n04560804.tsv
# Processing: n02226429.tsv
# Processing: n02165456.tsv
# Processing: n03513137.tsv
# Processing: n06359193.tsv
# Processing: n04379243.tsv
# Processing: n01855032.tsv
# Processing: n03773035.tsv
# Processing: n02799071.tsv
# Processing: n03636248.tsv
# Processing: n03803284.tsv
# Processing: n03903868.tsv
# Processing: n03814906.tsv
# Processing: n04428191.tsv
# Processing: n01605630.tsv
# Processing: n01503061.tsv
# Processing: n01784675.tsv
# Processing: n04067472.tsv
# Processing: n07874780.tsv
# Processing: n03001627.tsv
# Processing: n04194289.tsv
# Processing: n02169497.tsv
# Processing: n02802544.tsv
# Processing: n04243546.tsv
# Processing: n02132136.tsv
# Processing: n02259212.tsv
# Processing: n03505667.tsv
# Processing: n04456115.tsv
# Processing: n02281406.tsv
# Processing: n03837869.tsv
# Processing: n03416489.tsv
# Processing: n03599486.tsv
# Processing: n02084071.tsv
# Processing: n01641577.tsv
# Processing: n02077923.tsv
# Processing: n03325088.tsv
# Processing: n02231487.tsv
# Processing: n03089624.tsv
# Processing: n04540053.tsv
# Processing: n01871265.tsv
# Processing: n03998194.tsv
# Processing: n02321529.tsv
# Processing: n03329302.tsv
# Processing: n03665366.tsv
# Processing: n03642806.tsv
# Processing: n02788148.tsv
# Processing: n01986214.tsv
# Processing: n03273913.tsv
# Processing: n01774384.tsv
# Processing: n02892201.tsv
# Processing: n02815834.tsv
# Processing: n03733281.tsv
# Processing: n02374451.tsv
# All done.

# %%
# Confirm the one-bounding box assumption

import os, os.path
import xml.etree.ElementTree as ET

bbox_annotations_path = 'data/bbox/Annotation/'

synsets = [f for f in os.listdir(bbox_annotations_path)
                if not os.path.isfile(os.path.join(bbox_annotations_path, f))]

i = 0
mbbox_count = 0
for synset in synsets:
    
    dir_path = bbox_annotations_path + synset + "/"
    files = [f for f in os.listdir(dir_path)
                 if os.path.isfile(os.path.join(dir_path, f))]
        
    print("Processing synset " + str(i) + ": " + synset)
    
    for file in files:
        correction_performed = False

        # Traverse XML tree and get the relevant values
        tree = ET.parse(dir_path + str(file))
        root = tree.getroot()

        filename = [child for child in root if child.tag == "filename"][0].text
        size = [child for child in root if child.tag == "size"][0]

        width = int([child for child in size if child.tag == "width"][0].text)
        height = int([child for child in size if child.tag == "height"][0].text)

        obj = [child for child in root if child.tag == "object"][0]
        # AFAIK there is only one bounding box label per image
        bndboxes = [child for child in obj if child.tag == "bndbox"]
        if len(bndboxes) > 1:
            print(" WARN: More than one bounding box")
            mbbox_count += 1
    
    i+=1
    
print(str(mbbox_count))
# Out:
# Processing synset 0: n07867324
# Processing synset 1: n02773037
# Processing synset 2: n12305089
# Processing synset 3: n03692522
# Processing synset 4: n03291819
# Processing synset 5: n11709674
# Processing synset 6: n02129991
# Processing synset 7: n04497801
# Processing synset 8: n04179913
# Processing synset 9: n04489008
# Processing synset 10: n02339376
# Processing synset 11: n02097474
# Processing synset 12: n04379964
# Processing synset 13: n00467719
# Processing synset 14: n04127521
# Processing synset 15: n07844042
# Processing synset 16: n03743016
# Processing synset 17: n02997391
# Processing synset 18: n07574504
# Processing synset 19: n07891726
# Processing synset 20: n02932693
# Processing synset 21: n07904395
# Processing synset 22: n07859583
# Processing synset 23: n07688265
# Processing synset 24: n13136316
# Processing synset 25: n01487506
# Processing synset 26: n04490091
# Processing synset 27: n03148324
# Processing synset 28: n04047401
# Processing synset 29: n02493793
# Processing synset 30: n03110669
# Processing synset 31: n03431243
# Processing synset 32: n07810907
# Processing synset 33: n09217230
# Processing synset 34: n04335209
# Processing synset 35: n11888800
# Processing synset 36: n02991302
# Processing synset 37: n01538200
# Processing synset 38: n02107142
# Processing synset 39: n03337494
# Processing synset 40: n02894605
# Processing synset 41: n04140631
# Processing synset 42: n03422771
# Processing synset 43: n03476991
# Processing synset 44: n01582220
# Processing synset 45: n03092656
# Processing synset 46: n02085374
# Processing synset 47: n03765128
# Processing synset 48: n07698250
# Processing synset 49: n02093256
# Processing synset 50: n03314780
# Processing synset 51: n02331046
# Processing synset 52: n03571942
# Processing synset 53: n04571292
# Processing synset 54: n04325704
# Processing synset 55: n02414290
# Processing synset 56: n03888257
# Processing synset 57: n03916031
# Processing synset 58: n04350458
# Processing synset 59: n03982430
# Processing synset 60: n03579982
# Processing synset 61: n12710917
# Processing synset 62: n04047733
# Processing synset 63: n03046921
# Processing synset 64: n11611758
# Processing synset 65: n02037110
# Processing synset 66: n02850950
# Processing synset 67: n07852045
# Processing synset 68: n02077923
# Processing synset 69: n03227184
# Processing synset 70: n01704323
# Processing synset 71: n04231693
# Processing synset 72: n03355925
# Processing synset 73: n02321529
# Processing synset 74: n11808721
# Processing synset 75: n01793085
# Processing synset 76: n01955084
# Processing synset 77: n04317175
# Processing synset 78: n09376526
# Processing synset 79: n03710721
# Processing synset 80: n02537525
# Processing synset 81: n02013177
# Processing synset 82: n02379081
# Processing synset 83: n02850732
# Processing synset 84: n02416820
# Processing synset 85: n03763968
# Processing synset 86: n04192698
# Processing synset 87: n01615121
# Processing synset 88: n04449700
# Processing synset 89: n07913644
# Processing synset 90: n07556637
# Processing synset 91: n02881193
# Processing synset 92: n04194289
# Processing synset 93: n02508742
# Processing synset 94: n09415671
# Processing synset 95: n02821943
# Processing synset 96: n01981276
# Processing synset 97: n04501370
# Processing synset 98: n01688243
# Processing synset 99: n02774630
# Processing synset 100: n02951358
# Processing synset 101: n02381460
# Processing synset 102: n11947802
# Processing synset 103: n03624134
# Processing synset 104: n03863108
# Processing synset 105: n03943115
# Processing synset 106: n03721384
# Processing synset 107: n02421792
# Processing synset 108: n01514859
# Processing synset 109: n03261776
# Processing synset 110: n02370806
# Processing synset 111: n03014705
# Processing synset 112: n03151077
# Processing synset 113: n02486908
# Processing synset 114: n03618678
# Processing synset 115: n02096051
# Processing synset 116: n06794110
# Processing synset 117: n04591713
# Processing synset 118: n07852376
# Processing synset 119: n03173929
# Processing synset 120: n03857828
# Processing synset 121: n03142679
# Processing synset 122: n06277135
# Processing synset 123: n01729977
# Processing synset 124: n03724870
# Processing synset 125: n07732747
# Processing synset 126: n04312154
# Processing synset 127: n02749479
# Processing synset 128: n03004275
# Processing synset 129: n01546039
# Processing synset 130: n07879450
# Processing synset 131: n03268790
# Processing synset 132: n02426176
# Processing synset 133: n04496726
# Processing synset 134: n02386853
# Processing synset 135: n07872593
# Processing synset 136: n02443484
# Processing synset 137: n01889520
# Processing synset 138: n02767147
# Processing synset 139: n07906284
# Processing synset 140: n02149420
# Processing synset 141: n03706653
# Processing synset 142: n07871810
# Processing synset 143: n03543394
# Processing synset 144: n04442441
# Processing synset 145: n02908773
# Processing synset 146: n07831146
# Processing synset 147: n01835769
# Processing synset 148: n02381609
# Processing synset 149: n01694178
# Processing synset 150: n03012159
# Processing synset 151: n04453037
# Processing synset 152: n02123045
# Processing synset 153: n03852688
# Processing synset 154: n02110185
# Processing synset 155: n04238617
# Processing synset 156: n02117135
# Processing synset 157: n01950731
# Processing synset 158: n01876034
# Processing synset 159: n03098688
# Processing synset 160: n02101670
# Processing synset 161: n04126066
# Processing synset 162: n01774384
# Processing synset 163: n02395406
# Processing synset 164: n04059947
# Processing synset 165: n12741792
# Processing synset 166: n03179701
# Processing synset 167: n03122073
# Processing synset 168: n02824448
# Processing synset 169: n02807731
# Processing synset 170: n02142407
# Processing synset 171: n04509260
# Processing synset 172: n02538010
# Processing synset 173: n07579575
# Processing synset 174: n04123740
# Processing synset 175: n03631177
# Processing synset 176: n02408429
# Processing synset 177: n07739344
# Processing synset 178: n07579917
# Processing synset 179: n03819336
# Processing synset 180: n03216828
# Processing synset 181: n07891189
# Processing synset 182: n04003241
# Processing synset 183: n04026417
# Processing synset 184: n04458633
# Processing synset 185: n02494079
# Processing synset 186: n03329663
# Processing synset 187: n03224893
# Processing synset 188: n03365231
# Processing synset 189: n02129530
# Processing synset 190: n07680655
# Processing synset 191: n12768682
# Processing synset 192: n04335435
# Processing synset 193: n03380724
# Processing synset 194: n01613294
# Processing synset 195: n02114712
# Processing synset 196: n11906917
# Processing synset 197: n04553703
# Processing synset 198: n03639497
# Processing synset 199: n09889941
# Processing synset 200: n03049457
# Processing synset 201: n03211117
# Processing synset 202: n02093991
# Processing synset 203: n03393017
# Processing synset 204: n11805956
# Processing synset 205: n06596364
# Processing synset 206: n02835915
# Processing synset 207: n04367480
# Processing synset 208: n03528100
# Processing synset 209: n03205143
# Processing synset 210: n04613696
# Processing synset 211: n04593077
# Processing synset 212: n07851443
# Processing synset 213: n03731019
# Processing synset 214: n04442312
# Processing synset 215: n07899108
# Processing synset 216: n02377603
# Processing synset 217: n02116738
# Processing synset 218: n02694662
# Processing synset 219: n07935043
# Processing synset 220: n02974003
# Processing synset 221: n04256520
# Processing synset 222: n09309168
# Processing synset 223: n01664065
# Processing synset 224: n03000684
# Processing synset 225: n06998748
# Processing synset 226: n03484083
# Processing synset 227: n01881171
# Processing synset 228: n04138977
# Processing synset 229: n04166281
# Processing synset 230: n03784793
# Processing synset 231: n01792955
# Processing synset 232: n03018209
# Processing synset 233: n12057447
# Processing synset 234: n01979526
# Processing synset 235: n03838899
# Processing synset 236: n02898269
# Processing synset 237: n02013706
# Processing synset 238: n02483362
# Processing synset 239: n02568447
# Processing synset 240: n04543158
# Processing synset 241: n03912218
# Processing synset 242: n04376400
# Processing synset 243: n04241573
# Processing synset 244: n06272290
# Processing synset 245: n03926412
# Processing synset 246: n02887489
# Processing synset 247: n03652389
# Processing synset 248: n04277352
# Processing synset 249: n04304215
# Processing synset 250: n04209133
# Processing synset 251: n02071294
# Processing synset 252: n02095570
# Processing synset 253: n02503127
# Processing synset 254: n04498389
# Processing synset 255: n01924916
# Processing synset 256: n02428089
# Processing synset 257: n07729485
# Processing synset 258: n02092173
# Processing synset 259: n07842753
# Processing synset 260: n11759404
# Processing synset 261: n02130086
# Processing synset 262: n03790512
# Processing synset 263: n01828970
# Processing synset 264: n04108999
# Processing synset 265: n02125010
# Processing synset 266: n04330267
# Processing synset 267: n03365991
# Processing synset 268: n03445777
# Processing synset 269: n04021798
# Processing synset 270: n02933112
# Processing synset 271: n02366002
# Processing synset 272: n02493509
# Processing synset 273: n02072040
# Processing synset 274: n02361337
# Processing synset 275: n02364520
# Processing synset 276: n10624074
# Processing synset 277: n07929351
# Processing synset 278: n02086240
# Processing synset 279: n02426813
# Processing synset 280: n11901977
# Processing synset 281: n03928814
# Processing synset 282: n07904934
# Processing synset 283: n02788148
# Processing synset 284: n02870880
# Processing synset 285: n04507326
# Processing synset 286: n03020034
# Processing synset 287: n02906734
# Processing synset 288: n07593004
# Processing synset 289: n04264628
# Processing synset 290: n03874293
# Processing synset 291: n02096585
# Processing synset 292: n02372584
# Processing synset 293: n03447721
# Processing synset 294: n02098105
# Processing synset 295: n03598930
# Processing synset 296: n02727426
# Processing synset 297: n02919414
# Processing synset 298: n03422072
# Processing synset 299: n04209239
# Processing synset 300: n04587559
# Processing synset 301: n02886434
# Processing synset 302: n07742313
# Processing synset 303: n03116767
# Processing synset 304: n04246731
# Processing synset 305: n02384741
# Processing synset 306: n03908714
# Processing synset 307: n03341606
# Processing synset 308: n03630383
# Processing synset 309: n02009912
# Processing synset 310: n03341153
# Processing synset 311: n07767549
# Processing synset 312: n07581346
# Processing synset 313: n02414578
# Processing synset 314: n02931417
# Processing synset 315: n07772788
# Processing synset 316: n04485082
# Processing synset 317: n07820497
# Processing synset 318: n03978966
# Processing synset 319: n03017168
# Processing synset 320: n01857079
# Processing synset 321: n03820318
# Processing synset 322: n03577672
# Processing synset 323: n13134947
# Processing synset 324: n02128925
# Processing synset 325: n03544143
# Processing synset 326: n03837869
# Processing synset 327: n01751748
# Processing synset 328: n02692086
# Processing synset 329: n02380745
# Processing synset 330: n03939565
# Processing synset 331: n02256656
# Processing synset 332: n07868830
# Processing synset 333: n04164868
# Processing synset 334: n03954731
# Processing synset 335: n02858304
# Processing synset 336: n02095412
# Processing synset 337: n07936979
# Processing synset 338: n03791053
# Processing synset 339: n02000954
# Processing synset 340: n04144539
# Processing synset 341: n01728572
# Processing synset 342: n07697537
# Processing synset 343: n03886762
# Processing synset 344: n01689811
# Processing synset 345: n07905618
# Processing synset 346: n02119022
# Processing synset 347: n02950632
# Processing synset 348: n03018712
# Processing synset 349: n02776631
# Processing synset 350: n04610013
# Processing synset 351: n04350769
# Processing synset 352: n02672831
# Processing synset 353: n07716906
# Processing synset 354: n02966193
# Processing synset 355: n02437312
# Processing synset 356: n04414476
# Processing synset 357: n04186051
# Processing synset 358: n03120491
# Processing synset 359: n02353411
# Processing synset 360: n03541923
# Processing synset 361: n15092650
# Processing synset 362: n03574816
# Processing synset 363: n00445351
# Processing synset 364: n04472243
# Processing synset 365: n12278650
# Processing synset 366: n02770211
# Processing synset 367: n11814584
# Processing synset 368: n03643253
# Processing synset 369: n04199027
# Processing synset 370: n03510244
# Processing synset 371: n03395256
# Processing synset 372: n03273551
# Processing synset 373: n11857875
# Processing synset 374: n02205219
# Processing synset 375: n07897116
# Processing synset 376: n02492660
# Processing synset 377: n02952109
# Processing synset 378: n01860187
# Processing synset 379: n07910245
# Processing synset 380: n02377703
# Processing synset 381: n07736692
# Processing synset 382: n07805731
# Processing synset 383: n02984061
# Processing synset 384: n11859737
# Processing synset 385: n03788365
# Processing synset 386: n07714990
# Processing synset 387: n01518878
# Processing synset 388: n12043836
# Processing synset 389: n04192858
# Processing synset 390: n01683558
# Processing synset 391: n03920288
# Processing synset 392: n03978686
# Processing synset 393: n02108254
# Processing synset 394: n03885535
# Processing synset 395: n07920052
# Processing synset 396: n07857959
# Processing synset 397: n04373894
# Processing synset 398: n02823750
# Processing synset 399: n02882647
# Processing synset 400: n07864934
# Processing synset 401: n04363082
# Processing synset 402: n02445715
# Processing synset 403: n02326763
# Processing synset 404: n03657121
# Processing synset 405: n03905947
# Processing synset 406: n07893425
# Processing synset 407: n02431628
# Processing synset 408: n03721047
# Processing synset 409: n04346328
# Processing synset 410: n07723039
# Processing synset 411: n08649711
# Processing synset 412: n03314884
# Processing synset 413: n04520382
# Processing synset 414: n02920259
# Processing synset 415: n02344528
# Processing synset 416: n01795545
# Processing synset 417: n02814860
# Processing synset 418: n03498962
# Processing synset 419: n07744811
# Processing synset 420: n07596967
# Processing synset 421: n07730033
# Processing synset 422: n02430045
# Processing synset 423: n02012849
# Processing synset 424: n02027492
# Processing synset 425: n02041246
# Processing synset 426: n07718472
# Processing synset 427: n03794056
# Processing synset 428: n07886176
# Processing synset 429: n11960245
# Processing synset 430: n04120842
# Processing synset 431: n04358707
# Processing synset 432: n03599486
# Processing synset 433: n12513933
# Processing synset 434: n02882894
# Processing synset 435: n01675722
# Processing synset 436: n12282933
# Processing synset 437: n02106854
# Processing synset 438: n03281145
# Processing synset 439: n01537544
# Processing synset 440: n02402010
# Processing synset 441: n12717072
# Processing synset 442: n12051103
# Processing synset 443: n08494231
# Processing synset 444: n04204081
# Processing synset 445: n03781787
# Processing synset 446: n04282872
# Processing synset 447: n04596742
# Processing synset 448: n02756098
# Processing synset 449: n02413050
# Processing synset 450: n07724269
# Processing synset 451: n07714571
# Processing synset 452: n03891251
# Processing synset 453: n07823105
# Processing synset 454: n03122202
# Processing synset 455: n09265620
# Processing synset 456: n03051396
# Processing synset 457: n09193705
# Processing synset 458: n03678558
# Processing synset 459: n04360798
# Processing synset 460: n07766173
# Processing synset 461: n02768226
# Processing synset 462: n03359436
# Processing synset 463: n03787032
# Processing synset 464: n04097373
# Processing synset 465: n07572616
# Processing synset 466: n11901597
# Processing synset 467: n02351870
# Processing synset 468: n02455135
# Processing synset 469: n04317976
# Processing synset 470: n02990373
# Processing synset 471: n02109961
# Processing synset 472: n02509197
# Processing synset 473: n02152881
# Processing synset 474: n04026918
# Processing synset 475: n02410509
# Processing synset 476: n07599649
# Processing synset 477: n03580615
# Processing synset 478: n01443537
# Processing synset 479: n03050546
# Processing synset 480: n04000592
# Processing synset 481: n02075296
# Processing synset 482: n04284002
# Processing synset 483: n07860988
# Processing synset 484: n12651821
# Processing synset 485: n07730406
# Processing synset 486: n04299215
# Processing synset 487: n04587404
# Processing synset 488: n04050066
# Processing synset 489: n04061681
# Processing synset 490: n04464615
# Processing synset 491: n04459362
# Processing synset 492: n04230487
# Processing synset 493: n02501583
# Processing synset 494: n02009229
# Processing synset 495: n04288272
# Processing synset 496: n04191595
# Processing synset 497: n03063073
# Processing synset 498: n04009552
# Processing synset 499: n03062245
# Processing synset 500: n03052464
# Processing synset 501: n12587803
# Processing synset 502: n04556948
# Processing synset 503: n02231487
# Processing synset 504: n03709823
# Processing synset 505: n03134739
# Processing synset 506: n02690373
# Processing synset 507: n07614500
# Processing synset 508: n03426134
# Processing synset 509: n03793850
# Processing synset 510: n03770439
# Processing synset 511: n02104184
# Processing synset 512: n01318894
# Processing synset 513: n04161358
# Processing synset 514: n04105893
# Processing synset 515: n01482330
# Processing synset 516: n07718747
# Processing synset 517: n02420509
# Processing synset 518: n03512147
# Processing synset 519: n03067339
# Processing synset 520: n03409393
# Processing synset 521: n03474779
# Processing synset 522: n03540090
# Processing synset 523: n03370387
# Processing synset 524: n04594828
# Processing synset 525: n11672400
# Processing synset 526: n06281040
# Processing synset 527: n01882714
# Processing synset 528: n02439033
# Processing synset 529: n02095889
# Processing synset 530: n02472987
# Processing synset 531: n02138169
# Processing synset 532: n03500699
# Processing synset 533: n01817953
# Processing synset 534: n02687821
# Processing synset 535: n02090622
# Processing synset 536: n12086012
# Processing synset 537: n02921029
# Processing synset 538: n02782093
# Processing synset 539: n04590021
# Processing synset 540: n03996004
# Processing synset 541: n03733805
# Processing synset 542: n03200906
# Processing synset 543: n04141975
# Processing synset 544: n03584400
# Processing synset 545: n03545150
# Processing synset 546: n02436353
# Processing synset 547: n02742753
# Processing synset 548: n07806221
# Processing synset 549: n03908618
# Processing synset 550: n02998563
# Processing synset 551: n12884260
# Processing synset 552: n02480495
# Processing synset 553: n03220692
# Processing synset 554: n01889074
# Processing synset 555: n09835506
# Processing synset 556: n04379243
# Processing synset 557: n04190052
# Processing synset 558: n03343737
# Processing synset 559: n04133789
# Processing synset 560: n03367059
# Processing synset 561: n06892775
# Processing synset 562: n11611356
# Processing synset 563: n02728440
# Processing synset 564: n04407435
# Processing synset 565: n12836862
# Processing synset 566: n04251144
# Processing synset 567: n01773549
# Processing synset 568: n01569566
# Processing synset 569: n04105068
# Processing synset 570: n03814906
# Processing synset 571: n07598928
# Processing synset 572: n07769731
# Processing synset 573: n03858418
# Processing synset 574: n07585644
# Processing synset 575: n03180011
# Processing synset 576: n03281524
# Processing synset 577: n03150511
# Processing synset 578: n07690273
# Processing synset 579: n04592005
# Processing synset 580: n03724066
# Processing synset 581: n02364840
# Processing synset 582: n03686130
# Processing synset 583: n02128385
# Processing synset 584: n07932841
# Processing synset 585: n02106382
# Processing synset 586: n02787622
# Processing synset 587: n02111129
# Processing synset 588: n02960352
# Processing synset 589: n03197337
# Processing synset 590: n04028315
# Processing synset 591: n03761084
# Processing synset 592: n04033995
# Processing synset 593: n02607470
# Processing synset 594: n02442845
# Processing synset 595: n02890804
# Processing synset 596: n02526121
# Processing synset 597: n07577374
# Processing synset 598: n04037964
# Processing synset 599: n01739381
# Processing synset 600: n03814639
# Processing synset 601: n07597145
# Processing synset 602: n03384167
# Processing synset 603: n03776460
# Processing synset 604: n03207743
# Processing synset 605: n03500389
# Processing synset 606: n02279972
# Processing synset 607: n07601809
# Processing synset 608: n04525305
# Processing synset 609: n03593526
# Processing synset 610: n03388043
# Processing synset 611: n07734292
# Processing synset 612: n07920349
# Processing synset 613: n12023407
# Processing synset 614: n02797692
# Processing synset 615: n03017698
# Processing synset 616: n07614198
# Processing synset 617: n02419796
# Processing synset 618: n04521571
# Processing synset 619: n04115996
# Processing synset 620: n07816296
# Processing synset 621: n03532919
# Processing synset 622: n03920867
# Processing synset 623: n04317420
# Processing synset 624: n10694258
# Processing synset 625: n03691459
# Processing synset 626: n04153025
# Processing synset 627: n02102973
# Processing synset 628: n02499808
# Processing synset 629: n07568818
# Processing synset 630: n03026506
# Processing synset 631: n03939062
# Processing synset 632: n02113624
# Processing synset 633: n04429376
# Processing synset 634: n02112706
# Processing synset 635: n02414763
# Processing synset 636: n04239074
# Processing synset 637: n03502331
# Processing synset 638: n02448318
# Processing synset 639: n11756669
# Processing synset 640: n07567139
# Processing synset 641: n02912065
# Processing synset 642: n02796995
# Processing synset 643: n04549028
# Processing synset 644: n02116450
# Processing synset 645: n07936015
# Processing synset 646: n04462240
# Processing synset 647: n04445952
# Processing synset 648: n02084071
# Processing synset 649: n02096756
# Processing synset 650: n03109150
# Processing synset 651: n04370048
# Processing synset 652: n09435739
# Processing synset 653: n07931280
# Processing synset 654: n03075370
# Processing synset 655: n03467984
# Processing synset 656: n07609407
# Processing synset 657: n02500267
# Processing synset 658: n02404186
# Processing synset 659: n02899439
# Processing synset 660: n04004990
# Processing synset 661: n03012897
# Processing synset 662: n02608996
# Processing synset 663: n12691428
# Processing synset 664: n04125021
# Processing synset 665: n02489166
# Processing synset 666: n03532342
# Processing synset 667: n02413131
# Processing synset 668: n02137549
# Processing synset 669: n04046974
# Processing synset 670: n07751451
# Processing synset 671: n00015388
# Processing synset 672: n02871439
# Processing synset 673: n01824575
# Processing synset 674: n12633994
# Processing synset 675: n07851926
# Processing synset 676: n07713763
# Processing synset 677: n03376771
# Processing synset 678: n03418242
# Processing synset 679: n02777292
# Processing synset 680: n07683617
# Processing synset 681: n03201996
# Processing synset 682: n07717556
# Processing synset 683: n03367410
# Processing synset 684: n01740131
# Processing synset 685: n02797295
# Processing synset 686: n02115096
# Processing synset 687: n00482298
# Processing synset 688: n03630262
# Processing synset 689: n04548362
# Processing synset 690: n12056217
# Processing synset 691: n07575984
# Processing synset 692: n02281787
# Processing synset 693: n02085936
# Processing synset 694: n02136794
# Processing synset 695: n02122430
# Processing synset 696: n04206790
# Processing synset 697: n07893642
# Processing synset 698: n07818277
# Processing synset 699: n04252077
# Processing synset 700: n03558404
# Processing synset 701: n07772274
# Processing synset 702: n04407686
# Processing synset 703: n07624924
# Processing synset 704: n04347754
# Processing synset 705: n03016953
# Processing synset 706: n02826886
# Processing synset 707: n03237212
# Processing synset 708: n03621694
# Processing synset 709: n07575076
# Processing synset 710: n07893792
# Processing synset 711: n04177041
# Processing synset 712: n02761834
# Processing synset 713: n02352591
# Processing synset 714: n09288635
# Processing synset 715: n03100240
# Processing synset 716: n02090827
# Processing synset 717: n04188179
# Processing synset 718: n02848921
# Processing synset 719: n04399046
# Processing synset 720: n02010453
# Processing synset 721: n03237340
# Processing synset 722: n03138669
# Processing synset 723: n04121228
# Processing synset 724: n03938401
# Processing synset 725: n12727101
# Processing synset 726: n07734744
# Processing synset 727: n13040303
# Processing synset 728: n12683407
# Processing synset 729: n01693334
# Processing synset 730: n04149813
# Processing synset 731: n02006656
# Processing synset 732: n03160309
# Processing synset 733: n02113712
# Processing synset 734: n02786058
# Processing synset 735: n04326547
# Processing synset 736: n01953361
# Processing synset 737: n03041632
# Processing synset 738: n03467517
# Processing synset 739: n04326896
# Processing synset 740: n04285965
# Processing synset 741: n07848338
# Processing synset 742: n03459775
# Processing synset 743: n04402449
# Processing synset 744: n03089624
# Processing synset 745: n04127117
# Processing synset 746: n02946348
# Processing synset 747: n01639765
# Processing synset 748: n03900979
# Processing synset 749: n02391994
# Processing synset 750: n02951585
# Processing synset 751: n00483705
# Processing synset 752: n04532670
# Processing synset 753: n03766508
# Processing synset 754: n02102040
# Processing synset 755: n02818832
# Processing synset 756: n06596474
# Processing synset 757: n00007846
# Processing synset 758: n02425532
# Processing synset 759: n07692614
# Processing synset 760: n02433729
# Processing synset 761: n07748912
# Processing synset 762: n03085602
# Processing synset 763: n12284262
# Processing synset 764: n02914991
# Processing synset 765: n07871335
# Processing synset 766: n03772584
# Processing synset 767: n02089725
# Processing synset 768: n07611991
# Processing synset 769: n07695742
# Processing synset 770: n04556408
# Processing synset 771: n01876326
# Processing synset 772: n03011741
# Processing synset 773: n03476684
# Processing synset 774: n08249459
# Processing synset 775: n04428191
# Processing synset 776: n12708293
# Processing synset 777: n12345899
# Processing synset 778: n03788195
# Processing synset 779: n03338821
# Processing synset 780: n04589593
# Processing synset 781: n02955065
# Processing synset 782: n11669921
# Processing synset 783: n02782602
# Processing synset 784: n02017213
# Processing synset 785: n03211789
# Processing synset 786: n03522100
# Processing synset 787: n02568087
# Processing synset 788: n02110958
# Processing synset 789: n02082791
# Processing synset 790: n07873807
# Processing synset 791: n03046257
# Processing synset 792: n13104059
# Processing synset 793: n07926346
# Processing synset 794: n04027023
# Processing synset 795: n07915491
# Processing synset 796: n03471779
# Processing synset 797: n02381004
# Processing synset 798: n09399592
# Processing synset 799: n02836035
# Processing synset 800: n04311174
# Processing synset 801: n01737021
# Processing synset 802: n11901294
# Processing synset 803: n01943899
# Processing synset 804: n01484850
# Processing synset 805: n02947818
# Processing synset 806: n04023962
# Processing synset 807: n04251701
# Processing synset 808: n11978713
# Processing synset 809: n04000311
# Processing synset 810: n01669191
# Processing synset 811: n11615026
# Processing synset 812: n02427576
# Processing synset 813: n09230041
# Processing synset 814: n01665541
# Processing synset 815: n03173387
# Processing synset 816: n07889510
# Processing synset 817: n03834040
# Processing synset 818: n02329401
# Processing synset 819: n02090379
# Processing synset 820: n04180229
# Processing synset 821: n11703669
# Processing synset 822: n04542943
# Processing synset 823: n02092468
# Processing synset 824: n01858441
# Processing synset 825: n04404997
# Processing synset 826: n04118021
# Processing synset 827: n02455428
# Processing synset 828: n03894379
# Processing synset 829: n02099429
# Processing synset 830: n02946921
# Processing synset 831: n04318131
# Processing synset 832: n02907391
# Processing synset 833: n07743902
# Processing synset 834: n02096294
# Processing synset 835: n01726692
# Processing synset 836: n12304703
# Processing synset 837: n01855032
# Processing synset 838: n07578093
# Processing synset 839: n02932400
# Processing synset 840: n12055516
# Processing synset 841: n03744684
# Processing synset 842: n12496427
# Processing synset 843: n04252331
# Processing synset 844: n02177972
# Processing synset 845: n02416104
# Processing synset 846: n07892813
# Processing synset 847: n04165945
# Processing synset 848: n02489589
# Processing synset 849: n12966945
# Processing synset 850: n03234952
# Processing synset 851: n03846677
# Processing synset 852: n07801508
# Processing synset 853: n07720277
# Processing synset 854: n02709637
# Processing synset 855: n06267758
# Processing synset 856: n02062744
# Processing synset 857: n02129604
# Processing synset 858: n02491107
# Processing synset 859: n03416640
# Processing synset 860: n03877674
# Processing synset 861: n03271030
# Processing synset 862: n03394149
# Processing synset 863: n02110627
# Processing synset 864: n03188531
# Processing synset 865: n10514429
# Processing synset 866: n12830222
# Processing synset 867: n01687978
# Processing synset 868: n02081927
# Processing synset 869: n07838073
# Processing synset 870: n04228581
# Processing synset 871: n03218198
# Processing synset 872: n12266796
# Processing synset 873: n02770585
# Processing synset 874: n07625061
# Processing synset 875: n02993194
# Processing synset 876: n03272239
# Processing synset 877: n03546340
# Processing synset 878: n02064338
# Processing synset 879: n01447331
# Processing synset 880: n02416519
# Processing synset 881: n01531178
# Processing synset 882: n04479046
# Processing synset 883: n02667093
# Processing synset 884: n07926250
# Processing synset 885: n04549919
# Processing synset 886: n02428508
# Processing synset 887: n03036022
# Processing synset 888: n02970849
# Processing synset 889: n01843383
# Processing synset 890: n01852142
# Processing synset 891: n07721678
# Processing synset 892: n02355227
# Processing synset 893: n02488291
# Processing synset 894: n07642361
# Processing synset 895: n01594787
# Processing synset 896: n02099601
# Processing synset 897: n07761954
# Processing synset 898: n03333610
# Processing synset 899: n04562935
# Processing synset 900: n04315342
# Processing synset 901: n07814487
# Processing synset 902: n11904109
# Processing synset 903: n02755984
# Processing synset 904: n02895154
# Processing synset 905: n04128499
# Processing synset 906: n07843464
# Processing synset 907: n02954340
# Processing synset 908: n04147793
# Processing synset 909: n04401088
# Processing synset 910: n04165675
# Processing synset 911: n07615289
# Processing synset 912: n02401031
# Processing synset 913: n04036303
# Processing synset 914: n02412080
# Processing synset 915: n07686873
# Processing synset 916: n12076577
# Processing synset 917: n02085272
# Processing synset 918: n02535759
# Processing synset 919: n01776313
# Processing synset 920: n12570394
# Processing synset 921: n12712626
# Processing synset 922: n02110063
# Processing synset 923: n01945685
# Processing synset 924: n02094931
# Processing synset 925: n01752736
# Processing synset 926: n03517899
# Processing synset 927: n04402984
# Processing synset 928: n03405725
# Processing synset 929: n03032252
# Processing synset 930: n12267677
# Processing synset 931: n07835331
# Processing synset 932: n04008634
# Processing synset 933: n02581957
# Processing synset 934: n04392985
# Processing synset 935: n04341686
# Processing synset 936: n03058107
# Processing synset 937: n02107683
# Processing synset 938: n03262932
# Processing synset 939: n02949542
# Processing synset 940: n02319555
# Processing synset 941: n04099429
# Processing synset 942: n04148054
# Processing synset 943: n03825442
# Processing synset 944: n07747607
# Processing synset 945: n02281136
# Processing synset 946: n03585073
# Processing synset 947: n03995265
# Processing synset 948: n01772222
# Processing synset 949: n02918964
# Processing synset 950: n03290653
# Processing synset 951: n03089477
# Processing synset 952: n07902937
# Processing synset 953: n01581434
# Processing synset 954: n04041747
# Processing synset 955: n03929855
# Processing synset 956: n03634034
# Processing synset 957: n01644373
# Processing synset 958: n07929519
# Processing synset 959: n03000247
# Processing synset 960: n07770763
# Processing synset 961: n02124075
# Processing synset 962: n02496052
# Processing synset 963: n04216634
# Processing synset 964: n12989938
# Processing synset 965: n02699770
# Processing synset 966: n02358584
# Processing synset 967: n01796340
# Processing synset 968: n03505667
# Processing synset 969: n01885498
# Processing synset 970: n04591887
# Processing synset 971: n03272010
# Processing synset 972: n02493224
# Processing synset 973: n03416775
# Processing synset 974: n02128757
# Processing synset 975: n04460130
# Processing synset 976: n04183217
# Processing synset 977: n03940256
# Processing synset 978: n03837422
# Processing synset 979: n03936466
# Processing synset 980: n01843065
# Processing synset 981: n04395875
# Processing synset 982: n02089555
# Processing synset 983: n03149135
# Processing synset 984: n04128837
# Processing synset 985: n03928589
# Processing synset 986: n04345028
# Processing synset 987: n03035715
# Processing synset 988: n02956795
# Processing synset 989: n04548280
# Processing synset 990: n07908647
# Processing synset 991: n03653583
# Processing synset 992: n03584254
# Processing synset 993: n11908846
# Processing synset 994: n02398521
# Processing synset 995: n07608866
# Processing synset 996: n02421136
# Processing synset 997: n02964075
# Processing synset 998: n07579787
# Processing synset 999: n04433377
# Processing synset 1000: n04462011
# Processing synset 1001: n07694839
# Processing synset 1002: n07585557
# Processing synset 1003: n03495258
# Processing synset 1004: n07682316
# Processing synset 1005: n12154773
# Processing synset 1006: n01321579
# Processing synset 1007: n01873310
# Processing synset 1008: n07698672
# Processing synset 1009: n02330245
# Processing synset 1010: n04154565
# Processing synset 1011: n02247216
# Processing synset 1012: n04107743
# Processing synset 1013: n01743936
# Processing synset 1014: n03841666
# Processing synset 1015: n02839351
# Processing synset 1016: n03615655
# Processing synset 1017: n01532829
# Processing synset 1018: n03726760
# Processing synset 1019: n04487394
# Processing synset 1020: n02389026
# Processing synset 1021: n01494475
# Processing synset 1022: n03513137
# Processing synset 1023: n04608435
# Processing synset 1024: n04315713
# Processing synset 1025: n02378755
# Processing synset 1026: n13133613
# Processing synset 1027: n03727946
# Processing synset 1028: n02378415
# Processing synset 1029: n07690431
# Processing synset 1030: n01884476
# Processing synset 1031: n02968333
# Processing synset 1032: n06596845
# Processing synset 1033: n03521675
# Processing synset 1034: n02794972
# Processing synset 1035: n03259280
# Processing synset 1036: n06874185
# Processing synset 1037: n03623556
# Processing synset 1038: n11943992
# Processing synset 1039: n03928116
# Processing synset 1040: n07616386
# Processing synset 1041: n03726993
# Processing synset 1042: n04270147
# Processing synset 1043: n03135532
# Processing synset 1044: n02873520
# Processing synset 1045: n02087046
# Processing synset 1046: n07879174
# Processing synset 1047: n02114100
# Processing synset 1048: n04213105
# Processing synset 1049: n02729965
# Processing synset 1050: n02009380
# Processing synset 1051: n07605804
# Processing synset 1052: n04098795
# Processing synset 1053: n03379828
# Processing synset 1054: n07700003
# Processing synset 1055: n01892030
# Processing synset 1056: n03793489
# Processing synset 1057: n07881800
# Processing synset 1058: n07691237
# Processing synset 1059: n03801671
# Processing synset 1060: n04503413
# Processing synset 1061: n02169497
# Processing synset 1062: n07811416
# Processing synset 1063: n04426184
# Processing synset 1064: n07926442
# Processing synset 1065: n07902799
# Processing synset 1066: n07935288
# Processing synset 1067: n02407763
# Processing synset 1068: n13136556
# Processing synset 1069: n01630670
# Processing synset 1070: n02368116
# Processing synset 1071: n07875086
# Processing synset 1072: n07690892
# Processing synset 1073: n02869563
# Processing synset 1074: n07847585
# Processing synset 1075: n03992703
# Processing synset 1076: n04486054
# Processing synset 1077: n02504770
# Processing synset 1078: n03909406
# Processing synset 1079: n00468480
# Processing synset 1080: n04529681
# Processing synset 1081: n03478589
# Processing synset 1082: n03895866
# Processing synset 1083: n09472597
# Processing synset 1084: n02966687
# Processing synset 1085: n04108822
# Processing synset 1086: n07933274
# Processing synset 1087: n03262809
# Processing synset 1088: n02867715
# Processing synset 1089: n07892418
# Processing synset 1090: n03146219
# Processing synset 1091: n03976467
# Processing synset 1092: n07930864
# Processing synset 1093: n02472293
# Processing synset 1094: n15075141
# Processing synset 1095: n01917611
# Processing synset 1096: n01858845
# Processing synset 1097: n01887474
# Processing synset 1098: n02031934
# Processing synset 1099: n02390738
# Processing synset 1100: n03654826
# Processing synset 1101: n04294879
# Processing synset 1102: n03809312
# Processing synset 1103: n03961711
# Processing synset 1104: n04275548
# Processing synset 1105: n12199790
# Processing synset 1106: n02817516
# Processing synset 1107: n03870672
# Processing synset 1108: n03751269
# Processing synset 1109: n02108089
# Processing synset 1110: n12755727
# Processing synset 1111: n02429456
# Processing synset 1112: n02925385
# Processing synset 1113: n02908217
# Processing synset 1114: n03376159
# Processing synset 1115: n02323902
# Processing synset 1116: n01680655
# Processing synset 1117: n02848216
# Processing synset 1118: n07854184
# Processing synset 1119: n02103406
# Processing synset 1120: n04453156
# Processing synset 1121: n04061969
# Processing synset 1122: n07898617
# Processing synset 1123: n04220250
# Processing synset 1124: n07734017
# Processing synset 1125: n03792972
# Processing synset 1126: n04099969
# Processing synset 1127: n02152740
# Processing synset 1128: n11971406
# Processing synset 1129: n03244775
# Processing synset 1130: n02109150
# Processing synset 1131: n03166809
# Processing synset 1132: n04265275
# Processing synset 1133: n07734879
# Processing synset 1134: n01887896
# Processing synset 1135: n02419634
# Processing synset 1136: n04468005
# Processing synset 1137: n02455720
# Processing synset 1138: n02871963
# Processing synset 1139: n02105641
# Processing synset 1140: n11646344
# Processing synset 1141: n02071636
# Processing synset 1142: n02763901
# Processing synset 1143: n01978455
# Processing synset 1144: n07592656
# Processing synset 1145: n07572353
# Processing synset 1146: n03204558
# Processing synset 1147: n12920204
# Processing synset 1148: n02382039
# Processing synset 1149: n02111277
# Processing synset 1150: n04536866
# Processing synset 1151: n10148035
# Processing synset 1152: n02839910
# Processing synset 1153: n07683786
# Processing synset 1154: n03728437
# Processing synset 1155: n12749852
# Processing synset 1156: n07764155
# Processing synset 1157: n03015254
# Processing synset 1158: n03752185
# Processing synset 1159: n02101108
# Processing synset 1160: n12570972
# Processing synset 1161: n07850329
# Processing synset 1162: n11636835
# Processing synset 1163: n02916350
# Processing synset 1164: n04043733
# Processing synset 1165: n04012482
# Processing synset 1166: n12293723
# Processing synset 1167: n07704205
# Processing synset 1168: n02196896
# Processing synset 1169: n03344305
# Processing synset 1170: n03632729
# Processing synset 1171: n07681926
# Processing synset 1172: n02978881
# Processing synset 1173: n09450163
# Processing synset 1174: n07248320
# Processing synset 1175: n06272803
# Processing synset 1176: n03613294
# Processing synset 1177: n02421449
# Processing synset 1178: n02807133
# Processing synset 1179: n02884450
# Processing synset 1180: n02692232
# Processing synset 1181: n03494537
# Processing synset 1182: n02774152
# Processing synset 1183: n02949202
# Processing synset 1184: n02897820
# Processing synset 1185: n07712559
# Processing synset 1186: n02380583
# Processing synset 1187: n04102406
# Processing synset 1188: n02666196
# Processing synset 1189: n12049562
# Processing synset 1190: n07925966
# Processing synset 1191: n02364673
# Processing synset 1192: n03563200
# Processing synset 1193: n02100735
# Processing synset 1194: n04217882
# Processing synset 1195: n11979715
# Processing synset 1196: n12360108
# Processing synset 1197: n02089468
# Processing synset 1198: n11887119
# Processing synset 1199: n03977158
# Processing synset 1200: n03930313
# Processing synset 1201: n11736694
# Processing synset 1202: n07642933
# Processing synset 1203: n04252225
# Processing synset 1204: n02498153
# Processing synset 1205: n02877765
# Processing synset 1206: n11704093
# Processing synset 1207: n04392113
# Processing synset 1208: n04090263
# Processing synset 1209: n03541696
# Processing synset 1210: n02889425
# Processing synset 1211: n02484473
# Processing synset 1212: n02093647
# Processing synset 1213: n01915700
# Processing synset 1214: n02988304
# Processing synset 1215: n02381261
# Processing synset 1216: n04028581
# Processing synset 1217: n02324045
# Processing synset 1218: n02431337
# Processing synset 1219: n12754648
# Processing synset 1220: n04210120
# Processing synset 1221: n02088839
# Processing synset 1222: n03399677
# Processing synset 1223: n03098140
# Processing synset 1224: n04247011
# Processing synset 1225: n11971248
# Processing synset 1226: n03097362
# Processing synset 1227: n02403454
# Processing synset 1228: n13054560
# Processing synset 1229: n12754981
# Processing synset 1230: n03090000
# Processing synset 1231: n02090721
# Processing synset 1232: n07697825
# Processing synset 1233: n01321123
# Processing synset 1234: n02804414
# Processing synset 1235: n07650903
# Processing synset 1236: n07607832
# Processing synset 1237: n07900225
# Processing synset 1238: n03840681
# Processing synset 1239: n02961035
# Processing synset 1240: n13011595
# Processing synset 1241: n02676566
# Processing synset 1242: n02408817
# Processing synset 1243: n03335030
# Processing synset 1244: n04241394
# Processing synset 1245: n03423306
# Processing synset 1246: n12879527
# Processing synset 1247: n01853498
# Processing synset 1248: n03819595
# Processing synset 1249: n03445924
# Processing synset 1250: n12606438
# Processing synset 1251: n13069224
# Processing synset 1252: n07592922
# Processing synset 1253: n02332755
# Processing synset 1254: n02131653
# Processing synset 1255: n02092339
# Processing synset 1256: n07565083
# Processing synset 1257: n07881205
# Processing synset 1258: n01774750
# Processing synset 1259: n01596273
# Processing synset 1260: n07692517
# Processing synset 1261: n02992529
# Processing synset 1262: n01787835
# Processing synset 1263: n02800213
# Processing synset 1264: n03347037
# Processing synset 1265: n02132580
# Processing synset 1266: n04525038
# Processing synset 1267: n04542095
# Processing synset 1268: n07903962
# Processing synset 1269: n01319467
# Processing synset 1270: n01322604
# Processing synset 1271: n03710193
# Processing synset 1272: n03796401
# Processing synset 1273: n01579028
# Processing synset 1274: n07745466
# Processing synset 1275: n04224543
# Processing synset 1276: n03706229
# Processing synset 1277: n07569106
# Processing synset 1278: n03075097
# Processing synset 1279: n12058630
# Processing synset 1280: n07557434
# Processing synset 1281: n07765208
# Processing synset 1282: n03832673
# Processing synset 1283: n03442756
# Processing synset 1284: n02924116
# Processing synset 1285: n04482393
# Processing synset 1286: n01811909
# Processing synset 1287: n07856270
# Processing synset 1288: n04555700
# Processing synset 1289: n01685808
# Processing synset 1290: n02090129
# Processing synset 1291: n01956481
# Processing synset 1292: n03067518
# Processing synset 1293: n07866723
# Processing synset 1294: n02268443
# Processing synset 1295: n03063689
# Processing synset 1296: n03801880
# Processing synset 1297: n03945459
# Processing synset 1298: n03097673
# Processing synset 1299: n04594489
# Processing synset 1300: n02860415
# Processing synset 1301: n12290748
# Processing synset 1302: n09918248
# Processing synset 1303: n12544539
# Processing synset 1304: n12072722
# Processing synset 1305: n02281015
# Processing synset 1306: n02211444
# Processing synset 1307: n02319095
# Processing synset 1308: n07880458
# Processing synset 1309: n03807537
# Processing synset 1310: n02709763
# Processing synset 1311: n02631628
# Processing synset 1312: n04435180
# Processing synset 1313: n02097658
# Processing synset 1314: n02405440
# Processing synset 1315: n02074367
# Processing synset 1316: n07890970
# Processing synset 1317: n02484322
# Processing synset 1318: n03820154
# Processing synset 1319: n02091831
# Processing synset 1320: n02920164
# Processing synset 1321: n03145522
# Processing synset 1322: n07832592
# Processing synset 1323: n02415435
# Processing synset 1324: n10340312
# Processing synset 1325: n03101796
# Processing synset 1326: n12144580
# Processing synset 1327: n03652932
# Processing synset 1328: n01853195
# Processing synset 1329: n07663899
# Processing synset 1330: n02418770
# Processing synset 1331: n03939844
# Processing synset 1332: n12036226
# Processing synset 1333: n04040759
# Processing synset 1334: n01641391
# Processing synset 1335: n02804123
# Processing synset 1336: n00471613
# Processing synset 1337: n02774921
# Processing synset 1338: n02280649
# Processing synset 1339: n04230603
# Processing synset 1340: n03777754
# Processing synset 1341: n07910152
# Processing synset 1342: n03676483
# Processing synset 1343: n03249569
# Processing synset 1344: n02066245
# Processing synset 1345: n01752165
# Processing synset 1346: n02404432
# Processing synset 1347: n02018207
# Processing synset 1348: n02402425
# Processing synset 1349: n07655263
# Processing synset 1350: n03425595
# Processing synset 1351: n04286575
# Processing synset 1352: n04390977
# Processing synset 1353: n02747802
# Processing synset 1354: n11903671
# Processing synset 1355: n03725600
# Processing synset 1356: n03950228
# Processing synset 1357: n04431745
# Processing synset 1358: n04461879
# Processing synset 1359: n02102480
# Processing synset 1360: n12049282
# Processing synset 1361: n04127249
# Processing synset 1362: n07907943
# Processing synset 1363: n02933340
# Processing synset 1364: n07775050
# Processing synset 1365: n03049924
# Processing synset 1366: n04433585
# Processing synset 1367: n02382437
# Processing synset 1368: n02333819
# Processing synset 1369: n03748162
# Processing synset 1370: n07584110
# Processing synset 1371: n01820546
# Processing synset 1372: n02109525
# Processing synset 1373: n02920369
# Processing synset 1374: n03438863
# Processing synset 1375: n04560113
# Processing synset 1376: n02172182
# Processing synset 1377: n02114548
# Processing synset 1378: n02461128
# Processing synset 1379: n04578801
# Processing synset 1380: n02793495
# Processing synset 1381: n04211528
# Processing synset 1382: n10599806
# Processing synset 1383: n01871875
# Processing synset 1384: n02386746
# Processing synset 1385: n12523475
# Processing synset 1386: n02814428
# Processing synset 1387: n01824344
# Processing synset 1388: n02268853
# Processing synset 1389: n04310157
# Processing synset 1390: n01632458
# Processing synset 1391: n03232543
# Processing synset 1392: n03825788
# Processing synset 1393: n01560419
# Processing synset 1394: n03602883
# Processing synset 1395: n02488702
# Processing synset 1396: n10565667
# Processing synset 1397: n04456115
# Processing synset 1398: n12946849
# Processing synset 1399: n03649909
# Processing synset 1400: n02803934
# Processing synset 1401: n12333771
# Processing synset 1402: n04201297
# Processing synset 1403: n09416076
# Processing synset 1404: n03557840
# Processing synset 1405: n02487347
# Processing synset 1406: n07888465
# Processing synset 1407: n07771212
# Processing synset 1408: n01594372
# Processing synset 1409: n02821627
# Processing synset 1410: n02788021
# Processing synset 1411: n03930630
# Processing synset 1412: n03481172
# Processing synset 1413: n13037406
# Processing synset 1414: n04545305
# Processing synset 1415: n02093754
# Processing synset 1416: n03147509
# Processing synset 1417: n02871525
# Processing synset 1418: n02088094
# Processing synset 1419: n02491474
# Processing synset 1420: n03897943
# Processing synset 1421: n02971167
# Processing synset 1422: n01775062
# Processing synset 1423: n02451415
# Processing synset 1424: n04412097
# Processing synset 1425: n02820210
# Processing synset 1426: n02333909
# Processing synset 1427: n01819313
# Processing synset 1428: n02954938
# Processing synset 1429: n07686202
# Processing synset 1430: n02080415
# Processing synset 1431: n12983048
# Processing synset 1432: n04507155
# Processing synset 1433: n04524313
# Processing synset 1434: n11611561
# Processing synset 1435: n04513998
# Processing synset 1436: n03483823
# Processing synset 1437: n02107574
# Processing synset 1438: n02033041
# Processing synset 1439: n04397027
# Processing synset 1440: n02403820
# Processing synset 1441: n02884859
# Processing synset 1442: n02098806
# Processing synset 1443: n04065272
# ...
# Processing synset 3157: n03908204
# Processing synset 3158: n03790230
# Processing synset 3159: n02086478
# Processing synset 3160: n03665924
# Processing synset 3161: n07685031
# Processing synset 3162: n02126139
# Processing synset 3163: n02963821
# Processing synset 3164: n03633091
# Processing synset 3165: n01980166
# Processing synset 3166: n03868242
# Processing synset 3167: n03074380
# Processing synset 3168: n07933799
# Processing synset 3169: n04194127
# Processing synset 3170: n04440963
# Processing synset 3171: n03101517
# Processing synset 3172: n03394649
# Processing synset 3173: n07851767
# Processing synset 3174: n02993546
# Processing synset 3175: n00440039
# Processing synset 3176: n02010728
# Processing synset 3177: n07564796
# Processing synset 3178: n04487081
# Processing synset 3179: n02503517
# Processing synset 3180: n04515003
# Processing synset 3181: n03980874
# Processing synset 3182: n12093329
# Processing synset 3183: n11712282
# Processing synset 3184: n02840245
# Processing synset 3185: n12774299
# Processing synset 3186: n02076196
# Processing synset 3187: n03254737
# Processing synset 3188: n03358172
# Processing synset 3189: n02112826
# Processing synset 3190: n02815834
# Processing synset 3191: n01753488
# Processing synset 3192: n04232800
# Processing synset 3193: n12190410
# Processing synset 3194: n07912211
# Processing synset 3195: n03337140
# Processing synset 3196: n03245724
# Processing synset 3197: n09842047
# Processing synset 3198: n01963571
# Processing synset 3199: n03518829
# Processing synset 3200: n02163008
# Processing synset 3201: n03963645
# Processing synset 3202: n03020416
# Processing synset 3203: n07574602
# Processing synset 3204: n03029197
# Processing synset 3205: n02103181
# Processing synset 3206: n03208938
# Processing synset 3207: n02176261
# Processing synset 3208: n02738535
# Processing synset 3209: n03221720
# Processing synset 3210: n07605380
# Processing synset 3211: n07560331
# Processing synset 3212: n03939178
# Processing synset 3213: n02323449
# Processing synset 3214: n02412210
# Processing synset 3215: n03911767
# Processing synset 3216: n07615569
# Processing synset 3217: n03127925
# Processing synset 3218: n03977592
# Processing synset 3219: n02971579
# Processing synset 3220: n03990474
# Processing synset 3221: n12142085
# Processing synset 3222: n03036469
# Processing synset 3223: n03168107
# Processing synset 3224: n04409128
# Processing synset 3225: n03485794
# Processing synset 3226: n04204347
# Processing synset 3227: n02954163
# Processing synset 3228: n03842012
# Processing synset 3229: n07642742
# Processing synset 3230: n07568241
# Processing synset 3231: n04212282
# Processing synset 3232: n03414162
# Processing synset 3233: n02842573
# Processing synset 3234: n02274259
# Processing synset 3235: n02358712
# Processing synset 3236: n12059625
# Processing synset 3237: n03836062
# Processing synset 3238: n03358726
# Processing synset 3239: n01803078
# Processing synset 3240: n02107908
# Processing synset 3241: n04152593
# Processing synset 3242: n02488415
# Processing synset 3243: n03320519
# Processing synset 3244: n01606978
# Processing synset 3245: n02898711
# Processing synset 3246: n02726305
# Processing synset 3247: n04389033
# Processing synset 3248: n09453008
# Processing synset 3249: n07687469
# Processing synset 3250: n02328150
# Processing synset 3251: n02411705
# Processing synset 3252: n04371774
# Processing synset 3253: n03435593
# Processing synset 3254: n04126980
# Processing synset 3255: n04118776
# Processing synset 3256: n01644900
# Processing synset 3257: n02539424
# Processing synset 3258: n03637318
# Processing synset 3259: n03244047
# Processing synset 3260: n01812337
# Processing synset 3261: n12158031
# Processing synset 3262: n03686924
# Processing synset 3263: n04523525
# Processing synset 3264: n03427296
# Processing synset 3265: n03847471
# Processing synset 3266: n03802228
# Processing synset 3267: n04549122
# Processing synset 3268: n04233124
# Processing synset 3269: n02872752
# Processing synset 3270: n04292572
# Processing synset 3271: n02788572
# Processing synset 3272: n02072493
# Processing synset 3273: n00478262
# Processing synset 3274: n03632577
# Processing synset 3275: n03874823
# Processing synset 3276: n03977966
# Processing synset 3277: n04547592
# Processing synset 3278: n04238128
# Processing synset 3279: n04297098
# Processing synset 3280: n04047834
# Processing synset 3281: n01818515
# Processing synset 3282: n12281788
# Processing synset 3283: n04209613
# Processing synset 3284: n02102177
# Processing synset 3285: n02456275
# Processing synset 3286: n12047345
# Processing synset 3287: n03798610
# Processing synset 3288: n02885882
# Processing synset 3289: n03364156
# Processing synset 3290: n04334599
# Processing synset 3291: n02755823
# Processing synset 3292: n02106030
# Processing synset 3293: n00441824
# Processing synset 3294: n13050397
# Processing synset 3295: n04008385
# Processing synset 3296: n03220237
# Processing synset 3297: n07569644
# Processing synset 3298: n01887787
# Processing synset 3299: n03196217
# Processing synset 3300: n02831724
# Processing synset 3301: n03485198
# Processing synset 3302: n04039381
# Processing synset 3303: n02643566
# Processing synset 3304: n02470238
# Processing synset 3305: n04168199
# Processing synset 3306: n02091032
# Processing synset 3307: n02564403
# Processing synset 3308: n03079494
# Processing synset 3309: n03759954
# Processing synset 3310: n03187595
# Processing synset 3311: n04229816
# Processing synset 3312: n02865351
# Processing synset 3313: n07838441
# Processing synset 3314: n02450034
# Processing synset 3315: n02138441
# Processing synset 3316: n07576577
# Processing synset 3317: n07749446
# Processing synset 3318: n04331277
# Processing synset 3319: n01677366
# Processing synset 3320: n02002556
# Processing synset 3321: n11710393
# Processing synset 3322: n13068917
# Processing synset 3323: n04370456
# Processing synset 3324: n03665366
# Processing synset 3325: n04054670
# Processing synset 3326: n09337253
# Processing synset 3327: n02973904
# Processing synset 3328: n02453108
# Processing synset 3329: n04550184
# Processing synset 3330: n04011827
# Processing synset 3331: n02849154
# Processing synset 3332: n12047884
# Processing synset 3333: n07609316
# Processing synset 3334: n03684823
# Processing synset 3335: n12713866
# Processing synset 3336: n04446844
# Processing synset 3337: n02089867
# Processing synset 3338: n03718335
# Processing synset 3339: n04124202
# Processing synset 3340: n04149374
# Processing synset 3341: n03584829
# Processing synset 3342: n04115456
# Processing synset 3343: n12527738
# Processing synset 3344: n04254680
# Processing synset 3345: n03425413
# Processing synset 3346: n03250847
# Processing synset 3347: n02485688
# Processing synset 3348: n03028596
# Processing synset 3349: n03035252
# Processing synset 3350: n02108422
# Processing synset 3351: n03670208
# Processing synset 3352: n03225988
# Processing synset 3353: n02091134
# Processing synset 3354: n04044716
# Processing synset 3355: n02777734
# Processing synset 3356: n07567980
# Processing synset 3357: n07900825
# Processing synset 3358: n04025508
# Processing synset 3359: n02964634
# Processing synset 3360: n04004475
# Processing synset 3361: n07768230
# Processing synset 3362: n02973236
# Processing synset 3363: n04404412
# Processing synset 3364: n04208210
# Processing synset 3365: n07760859
# Processing synset 3366: n01847000
# Processing synset 3367: n02104523
# Processing synset 3368: n06470073
# Processing synset 3369: n09359803
# Processing synset 3370: n03790755
# Processing synset 3371: n11761202
# Processing synset 3372: n01855672
# Processing synset 3373: n03316406
# Processing synset 3374: n01698640
# Processing synset 3375: n03538037
# Processing synset 3376: n02883205
# Processing synset 3377: n02007558
# Processing synset 3378: n07803093
# Processing synset 3379: n02815950
# Processing synset 3380: n07836838
# Processing synset 3381: n07680416
# Processing synset 3382: n07687211
# Processing synset 3383: n04565375
# Processing synset 3384: n04020298
# Processing synset 3385: n07934032
# Processing synset 3386: n07875835
# Processing synset 3387: n02883344
# Processing synset 3388: n02980441
# Processing synset 3389: n02514041
# Processing synset 3390: n04474187
# Processing synset 3391: n02441942
# Processing synset 3392: n03309356
# Processing synset 3393: n04022434
# Processing synset 3394: n02097209
# Processing synset 3395: n04546081
# Processing synset 3396: n03672827
# Processing synset 3397: n03126385
# Processing synset 3398: n03764736
# Processing synset 3399: n11879895
# Processing synset 3400: n12301445
# Processing synset 3401: n03929091
# Processing synset 3402: n04373428
# Processing synset 3403: n02447366
# Processing synset 3404: n12130549
# Processing synset 3405: n03887697
# Processing synset 3406: n07580053
# Processing synset 3407: n02827606
# Processing synset 3408: n15019030
# Processing synset 3409: n12272883
# Processing synset 3410: n02932891
# Processing synset 3411: n04540255
# Processing synset 3412: n02481823
# Processing synset 3413: n04313503
# Processing synset 3414: n03545756
# Processing synset 3415: n01749939
# Processing synset 3416: n02096437
# Processing synset 3417: n03236580
# Processing synset 3418: n03752398
# Processing synset 3419: n12043673
# Processing synset 3420: n03436891
# Processing synset 3421: n03127747
# Processing synset 3422: n07880968
# Processing synset 3423: n03452741
# Processing synset 3424: n03604311
# Processing synset 3425: n03343354
# Processing synset 3426: n02504458
# Processing synset 3427: n03988170
# Processing synset 3428: n01742172
# Processing synset 3429: n04310018
# Processing synset 3430: n07743544
# Processing synset 3431: n02219486
# Processing synset 3432: n03561169
# Processing synset 3433: n04266014
# Processing synset 3434: n02411999
# Processing synset 3435: n04366367
# Processing synset 3436: n02170400
# Processing synset 3437: n02865665
# Processing synset 3438: n12985420
# Processing synset 3439: n07714448
# Processing synset 3440: n02856013
# Processing synset 3441: n02802426
# Processing synset 3442: n01829413
# Processing synset 3443: n03777568
# Processing synset 3444: n02701730
# Processing synset 3445: n02870526
# Processing synset 3446: n01768244
# Processing synset 3447: n04381724
# Processing synset 3448: n02374451
# Processing synset 3449: n03344393
# Processing synset 3450: n07762913
# Processing synset 3451: n07893253
# Processing synset 3452: n02105251
# Processing synset 3453: n04557522
# Processing synset 3454: n03792782
# Processing synset 3455: n03618101
# Processing synset 3456: n04317833
# Processing synset 3457: n04065789
# Processing synset 3458: n03063968
# Processing synset 3459: n03786096
# Processing synset 3460: n04247736
# Processing synset 3461: n01877812
# Processing synset 3462: n03720891
# Processing synset 3463: n06592281
# Processing synset 3464: n02276258
# Processing synset 3465: n03845190
# Processing synset 3466: n07694659
# Processing synset 3467: n07840027
# Processing synset 3468: n03416489
# Processing synset 3469: n02226429
# Processing synset 3470: n03649797
# Processing synset 3471: n03642806
# Processing synset 3472: n03425241
# Processing synset 3473: n02733524
# Processing synset 3474: n09403734
# Processing synset 3475: n03287733
# Processing synset 3476: n11971783
# Processing synset 3477: n03956157
# Processing synset 3478: n04257223
# Processing synset 3479: n02971356
# Processing synset 3480: n04101375
# Processing synset 3481: n07753113
# Processing synset 3482: n01832493
# Processing synset 3483: n07834774
# Processing synset 3484: n04411264
# Processing synset 3485: n07601686
# Processing synset 3486: n04406239
# Processing synset 3487: n02084861
# Processing synset 3488: n03924679
# Processing synset 3489: n03900194
# Processing synset 3490: n03359137
# Processing synset 3491: n07683490
# Processing synset 3492: n01792042
# Processing synset 3493: n03463381
# Processing synset 3494: n07936459
# Processing synset 3495: n04249415
# Processing synset 3496: n07842433
# Processing synset 3497: n01496331
# Processing synset 3498: n08613733
# Processing synset 3499: n02807616
# Processing synset 3500: n03884397
# Processing synset 3501: n03931980
# Processing synset 3502: n12987056
# Processing synset 3503: n07687053
# Processing synset 3504: n03904060
# Processing synset 3505: n03964495
# Processing synset 3506: n10019406
# Processing synset 3507: n10439851
# Processing synset 3508: n03235042
# Processing synset 3509: n02418465
# Processing synset 3510: n07757132
# Processing synset 3511: n02136103
# Processing synset 3512: n10077593
# Processing synset 3513: n07802417
# Processing synset 3514: n09409752
# Processing synset 3515: n04555400
# Processing synset 3516: n04582869
# Processing synset 3517: n01807496
# Processing synset 3518: n01734418
# Processing synset 3519: n09421951
# Processing synset 3520: n11782036
# Processing synset 3521: n00483205
# Processing synset 3522: n04541987
# Processing synset 3523: n07608339
# Processing synset 3524: n02281406
# Processing synset 3525: n03544360
# Processing synset 3526: n07863374
# Processing synset 3527: n03534580
# Processing synset 3528: n01321230
# Processing synset 3529: n02964196
# Processing synset 3530: n04212165
# Processing synset 3531: n04488202
# Processing synset 3532: n04190376
# Processing synset 3533: n02694045
# Processing synset 3534: n02391617
# Processing synset 3535: n02088992
# Processing synset 3536: n02877962
# Processing synset 3537: n03343853
# Processing synset 3538: n03482523
# Processing synset 3539: n01831360
# Processing synset 3540: n02951703
# Processing synset 3541: n03044934
# Processing synset 3542: n11793779
# Processing synset 3543: n04238763
# Processing synset 3544: n03124170
# Processing synset 3545: n01737875
# Processing synset 3546: n14696793
# Processing synset 3547: n03296328
# Processing synset 3548: n02123159
# Processing synset 3549: n03297495
# Processing synset 3550: n07861813
# Processing synset 3551: n12269241
# Processing synset 3552: n03801760
# Processing synset 3553: n02656670
# Processing synset 3554: n03775636
# Processing synset 3555: n01738601
# Processing synset 3556: n12754003
# Processing synset 3557: n02159955
# Processing synset 3558: n04235860
# Processing synset 3559: n12057211
# Processing synset 3560: n04045255
# Processing synset 3561: n12102133
# Processing synset 3562: n03339643
# Processing synset 3563: n02945813
# Processing synset 3564: n04344873
# Processing synset 3565: n07583197
# Processing synset 3566: n02438173
# Processing synset 3567: n07932039
# Processing synset 3568: n02317335
# Processing synset 3569: n07744246
# Processing synset 3570: n11710136
# Processing synset 3571: n07687789
# Processing synset 3572: n08182379
# Processing synset 3573: n02139199
# Processing synset 3574: n01483021
# Processing synset 3575: n02951843
# Processing synset 3576: n02410900
# Processing synset 3577: n03483316
# Processing synset 3578: n04355933
# Processing synset 3579: n02435853
# Processing synset 3580: n02912557
# Processing synset 3581: n01663401
# Processing synset 3582: n02134418
# Processing synset 3583: n02397096
# Processing synset 3584: n01871265
# Processing synset 3585: n14582716
# Processing synset 3586: n02828884
# Processing synset 3587: n02112018
# Processing synset 3588: n03941417
# Processing synset 3589: n03089753
# Processing synset 3590: n03333129
# Processing synset 3591: n02879718
# Processing synset 3592: n01791625
# Processing synset 3593: n04597066
# Processing synset 3594: n03962932
# Processing synset 3595: n11610047
# Processing synset 3596: n00464894
# Processing synset 3597: n03394916
# Processing synset 3598: n03461385
# Processing synset 3599: n02731629
# Processing synset 3600: n02283201
# Processing synset 3601: n03751757
# Processing synset 3602: n02014941
# Processing synset 3603: n00451186
# Processing synset 3604: n02085782
# Processing synset 3605: n03595614
# Processing synset 3606: n04335693
# Processing synset 3607: n02110806
# Processing synset 3608: n02445004
# Processing synset 3609: n02870676
# Processing synset 3610: n03868863
# Processing synset 3611: n12074867
# Processing synset 3612: n02975212
# Processing synset 3613: n01667114
# Processing synset 3614: n00523513
# Processing synset 3615: n12755225
# Processing synset 3616: n03782006
# Processing synset 3617: n04115256
# Processing synset 3618: n13066448
# Processing synset 3619: n03490006
# Processing synset 3620: n03390983
# Processing synset 3621: n03590841
# Processing synset 3622: n02727825
# Processing synset 3623: n02011805
# Processing synset 3624: n04540053
# Processing synset 3625: n04435653
# Processing synset 3626: n02963159
# 0
